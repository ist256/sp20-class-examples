# %% [markdown]
# # IST256 Lesson 10
# ## Dictionaries
#
# - Zybook Ch9
# - P4E Ch9
#
#
# ## Links
#
# - Participation: [https://poll.ist256.com](https://poll.ist256.com)
# - In-Class Questions: [http://bit.ly/ist256teams](http://bit.ly/ist256teams)

# %% [markdown]
# # Agenda
#
# - Dictionaries as key-value pairs.
# - Basic dictionary operations such as getting/setting keys and values
# - Common dictionary use cases, such as representing complex objects.
# - List of dictionary as an in-memory database of objects.
# - Using the json library to load and save dictionaries to files.

# %% [markdown]
# # Connect Activity
#
# Question: A Python Dictionary is a
# A. `Immutable Sequence Type`
# B. `Mutable Mapping Type`
# C. `Mutable Sequence Type`
# D. `Immutable Mapping Type`
#
# ### Vote Now: [https://poll.ist256.com](https://poll.ist256.com)

# %% [markdown]
# # Dictionaries
#
# - The **dict** type is designed to store key-value pairs. In Python this is known as a **mapping type**.
# **<font color='green'>font={‘Name’:’Arial’,’Size’: 8}</font>**
# - Python dictionaries are **mutable** which means you can change the values.
# - Dictionary values are accessed by **key** not by **index**.
# **<font color='green'>font[‘Name’] = “Courier”</font>**

# %% [markdown]
# # Watch Me Code 1
#
# ### Dictionary Basics:
# - Create a dictionary
# - Update its value
# - Print it out

# %% [markdown]
# # Dictionary Methods
#
# - Like **str** and **list**, the **dict** type has its own set of built-in functions.
# - https://docs.python.org/3/library/stdtypes.html#mapping-types-dict

# %% [markdown]
# # Watch Me Code 2
#
# ### Dictionary Methods:
# - Handling KeyError
# - using get()  to avoid KeyError
# - values()
# - keys()
# - delete a key

# %% [markdown]
# # Check Yourself: Dictionaries
#
# - What is the output on line 2?
#
# ![image.png](attachment:image.png)
#
# A. `2`
# B.`'2'`
# C. `6`
# D. `KeyError`
#
# ### Vote Now: [https://poll.ist256.com](https://poll.ist256.com)

# %% [markdown]
# # Dictionaries or Lists?
#
# - When do you use a Python **list** versus a **dict**?
# - **Lists** are for **<font color='violet'>multiple versions</font>** of the **<font color='blue'>same type</font>**.
# Ex: Student GPA's
# **<font color='green'>[3.4,2.8,4.0]</font>**
# - **Dictionaries** are for **<font color='violet'>single versions</font>** of **<font color='blue'>different types</font>**.
# Ex: One Student's Name, GPA and Major
# **<font color='green'>{ 'Name' : 'bob', 'GPA' : 3.4 }</font>**

# %% [markdown]
# # Python's List of Dictionary
#
# #### For representing complex data structures…
#
#   students = [  <span>&#8592;</span> **<font color='green'>List</font>**
#  { 'Name':'bob','GPA':3.4 },  <span>&#8592;</span> **<font color='green'>Dictionary</font>**
#  { 'Name':'sue','GPA':2.8 },
#  { 'Name':'kent','GPA':4.0 }
# ]

# %% [markdown]
# # Watch Me Code 3
#
# ### List of Dictionary:
# - Using type()
# - Method chaining to access values

# %% [markdown]
# # Check Yourself: Matching
#
# ### Given the following Python code, match the Python Expression to it's answer
# ![image.png](attachment:image.png)
# #### Question
# 1. **s[0]['GPA']**
# 2. s[3]['Name']
# 3. s[1]['name']
#
# #### Answers
# A. `3.4`
# B. `KeyError`
# C. `IndexError`
# D. `'sue'`

# %% [markdown]
# # Check Yourself: Matching
#
# ### Given the following Python code, match the Python Expression to it's answer
# ![image.png](attachment:image.png)
#
# #### Question
# 1. s[0]['GPA']
# 2. **s[3]['Name']**
# 3. s[1]['name']
#
# #### Answers
# A. `3.4`
# B. `KeyError`
# C. `IndexError`
# D. `'sue'`

# %% [markdown]
# # JSON and Python Dictionaries
#
# - JSON (**JavaScript Object Notation**) is a standard, human-readable  data format. It's a popular format for data on the web.
# - JSON Can be easily converted to lists of dictionaries using Python's **json** module.
# - Transferring JSON to Python is **decoding**.
# - Transferring Python to JSON is **encoding**.
# - **<font color='red'>This is easy to do in Python but challenging to do in most other languages.</font>**

# %% [markdown]
# # Watch Me Code 4
#
# - Decode JSON Data
# - Load into List of Dictionary
# - Access data to obtain output

# %% [markdown]
# # End-To-End Example
#
# ### European Country Locator
# - Load JSON data for Countries in Europe
# - Input a country
# - Output
#     - Region (Southern Europe)
#     - Neighboring Countries

# %% [markdown]
# # Conclusion Activity
#
# ### <font color='orange'>"One Important Thing"</font>
#
# Share **one important thing** you learned in class today!!!!
